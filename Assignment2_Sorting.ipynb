# %% [markdown]
# # Sorting Algorithms Assignment (CS201)
#
# This assignment covers **Selection Sort**, **Insertion Sort**, **Merge Sort (iterative)**, and **Quick/Code Sort (iterative)** — exactly as presented in class (no recursion).
#
# **Weighting:** 4 questions × 25% each = **100%**.
#
# **Rules**
# - Use only the approaches shown in class (no built‑ins like `list.sort()` or `sorted()` for the core algorithm steps).
# - For Merge Sort and Quick/Code Sort, **use the iterative versions** (as covered in lecture) — no recursion.
# - Show **intermediate steps** where asked (splitting/merging for Merge Sort; partitioning/stack updates for Quick/Code Sort).
# - The use of AI tools or AI-assisted code generation is strictly prohibited for this course. Submissions found to contain AI-generated code, or identifiable AI signatures, will be considered a violation of academic integrity and will result in academic consequences in accordance with university policy. All work submitted must represent your own independent effort.
# ---

# %% [markdown]
# ## Q1 (25%) — Selection Sort: Step Tracing & Analysis
#
# Given the list:
# ```
# [64, 25, 12, 22, 11, 90, 45, 33]
# ```
# **Tasks**
# 1. Using the Selection Sort version from class, show the state of the list after each outer‑loop pass.
# 2. Count the total number of comparisons and number of swaps performed by your run.
# 3. Explain briefly why the number of comparisons in Selection Sort does **not** depend on whether the list is already sorted.

# %%
def selction_sort(arr):
    n = len(arr)
    for i in range(n-1):
        min_index = i
        comparison = 0
        for j in range(i+1,n):
            comparison += 1
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i],arr[min_index] = arr[min_index],arr[i]
        print('Number of comparison:', comparison,'for pass:',i+1)
    return arr

# %% [raw]
# For this selection sort we have to move from left to right and look for the largest value.
#
# [64, 25, 12, 22, 11, 90, 45, 33]
#
# For pass 1:
#     Since we are going left to right, we compare 64 (where 64 is the current max value) with 25 and check whether 64 is bigger than 25 or not. Since 64 is the bigger number instead of swapping we keep moving forward comparing it with the next number. Here, the next bigger number than 64 is 90 and there are few numbers after 90, we now update the current max value i.e 90 and start comparing with the rest. Since 90 is bigger than 45 we move to 33 and 90 is still bigger than 33 and 33 is the last value in the list, we finnaly swap the value among the current max value with the last integer which is 33. After this pass, we can conclude that the Biggest value in the list is in the right position.
# [64, 25, 12, 22, 11, 33, 45, 90]
#
# For pass 2:
#     Since we know from Pass 1 that the largest number in the list is in the right place. We now reduce the length of comparison by 1. Now we again compare the values from left to right. Starting at 64, we can say that the next no value is bigger than 64 outside of comparing with 90, so 64 swaps it's position with the second last number i.e. 45. Hence, we can say that after the 2nd pass the 2nd biggest number is in the right place.
# [45, 25, 12, 22, 11, 33, 64, 90]
#
# For pass 3:
#     Now the 2nd biggest number in the list are in right order we reduce the length of comparison by 2. We again compare the values from left to right. In this pass we select 45 and compare it with the rest of the numbers. Since no other numbers are bigger than 45 we swap 45 with 33.
# [33, 25, 12, 22, 11, 45, 64, 90]
#
# For pass 4:
#     Now 3 biggest numbers are in their right order. We again start from the left and go right. In this case we start from 33 and compare it with the other numbers. since 33 is the largest number among the rest. We swap 33 with 11.
# [11, 25, 12, 22, 33, 45, 64, 90]
#
# For pass 5:
#     Now we take 11 and compare it with the rest. since 11 is less than 25, 25 is going to be the current max value and compare it with the rest. Since no number is bigger than 25, we swap 25 and 22.
# [11, 22, 12, 25, 33, 45, 64, 90]
#
# For pass 6:
#     Now again start from the left and go the right we start from 11 and start comparing. Since 11 is less than 22, 22 is going to be the current max value and compare it with the rest. Since no numbers are bigger than 22 we swap places with 12.
# [11, 12, 22, 25, 33, 45, 64, 90]
#
# For pass 7:
#     Now we compare 11 with the remaining value which in this case is 12. Since 11 is less than 12 and there are no other numbers for 12 to be compared with, no swap is performed and by this we can conclude that the numbers are now sorted in right order.
# [11, 12, 22, 25, 33, 45, 64, 90]

# %%
arr = [64, 25, 12, 22, 11, 90, 45, 33]
selction_sort(arr)
# Out:
# Number of comparison: 7 for pass: 1
# Number of comparison: 6 for pass: 2
# Number of comparison: 5 for pass: 3
# Number of comparison: 4 for pass: 4
# Number of comparison: 3 for pass: 5
# Number of comparison: 2 for pass: 6
# Number of comparison: 1 for pass: 7
# [11, 12, 22, 25, 33, 45, 64, 90]

# %% [raw]
# Initial:[64, 25, 12, 22, 11, 90, 45, 33]
# PASS 1:[64, 25, 12, 22, 11, 33, 45, 90] | Compared 7 times
# PASS 2:[45, 25, 12, 22, 11, 33, 64, 90] | Compared 6 times
# PASS 3:[33, 25, 12, 22, 11, 45, 64, 90] | Compared 5 times
# PASS 4:[11, 25, 12, 22, 33, 45, 64, 90] | Compared 4 times
# PASS 5:[11, 22, 12, 25, 33, 45, 64, 90] | Compared 3 times
# PASS 6:[11, 12, 22, 25, 33, 45, 64, 90] | Compared 2 times
# PASS 7:[11, 12, 22, 25, 33, 45, 64, 90] | Compared 1 times
#
# Total Number of comparisons: 28 Times

# %% [raw]
# The number of comparisons in Selection sort does not depend on whether the list is already sorted or not because in selection sort we compare the values from left to right no matter the order, we compare the current maximum values with rest of the numbers in the list until and unless we for a fact know that they are in the right position or right index. Also there isn't a way in selection sort to stop the execution early no matter what.

# %% [markdown]
# ## Q2 (25%) — Insertion Sort: Best vs. Worst Case
#
# Consider Insertion Sort on the following cases:
#
# - Case A (already sorted):
# ```
# [5, 10, 15, 20, 25, 30, 35, 40]
# ```
# - Case B (reverse sorted):
# ```
# [40, 35, 30, 25, 20, 15, 10, 5]
# ```
#
# **Tasks**
# 1. Trace and show the list after each insertion step for **Case B** only.
# 2. Report and compare the total number of element shifts/moves in Case A vs. Case B.
# 3. In 2–4 sentences, explain why Insertion Sort performs much better on nearly sorted data than Selection Sort.

# %%
def insertion_sort(arr):
    total_comparisons = 0
    total_shifts = 0
    total_moves = 0
    for i in range(1,len(arr)):
        comparisons = 0
        shifts = 0
        temp = arr[i]
        total_moves += 1
        j = i-1
        while j>=0 and arr[j]>temp:
            comparisons += 1
            arr[j+1] = arr[j]
            shifts +=1
            j-=1   
        arr[j+1] = temp 
        total_moves += 1
        total_comparisons += comparisons
        total_shifts += shifts
    print('Total Number of Comparisons:', total_comparisons)
    print('Total Number of shifts:', total_shifts)
    print('Total Number of Moves:', total_moves)
    return arr

# %% [raw]
# [40, 35, 30, 25, 20, 15, 10, 5]
#
# For pass 1:
#     Given array is a reverse Sorted array. Since this is a insertion sort. We start from the left side and go to the right side. Here we start from 40 and compare it with next unsorted value which is 35. Since 35 is less than 40 we swap them.
# [35, 40, 30, 25, 20, 15, 10, 5]
#
# For pass 2:
#     Now for this pass we start from the largest current value that is 40 and go to the right. we compare 40 with the next value that is 30. Since 30 is less than 40 we swap. Now also 30 can be compared with 35 and 30 is less than 35 we swap again.
# [30, 35, 40, 25, 20, 15, 10, 5]
#
# For pass 3:
#     Now we find next unsorted element that is 40 and 25. We compare them and since 25 is less than 40, we swap them. and the since 25 is still unsorted compared to elements on the left. Compare 25 with 35, since 25 is less than35 we swap again. And 25 is still not sorted we compare 25 and 30 since 25 is less than 30 we swap. Now 20 has no other elements to compare with so we end the pass there.
# [25, 30, 35, 40, 20, 15, 10, 5]
#
# For pass 4:
#     Now we again find the next unsorted element which is 40 with 20. We again compare, 20 is less than 40 so swap, 20 is also less than 35 so swap, 20 is again less than 30 so swap and finally 20 is less than 25 so swap again. Since 20 has no elements to be compared with we end the pass there.
# [20, 25, 30, 35, 40, 15, 10, 5]
#
# For pass 5:
#     Now again compare 40 and 15 cause it is the unsorted element. 15 less than 40 so swap, 15 less than 35 so swap, 15 less than 30 so swap, 15 less than 25 so swap and 15 less than 20 so swap. Since 15 has no other elements to compare with the pass ends there.
# [15, 20, 25, 30, 35, 40, 10, 5]
#
# For pass 6:
#     We compare 40 and 10, Since 10 is less than 40 we swap, 10 is less than 35 we swap, 10 is less than 30 we swap,10 is less than 25 we swap, 10 is less than 20 we swap and 10 is less than 15 we swap. 10 has no other element to be swap with so we end the pass there.
# [10, 15, 20, 25, 30, 35, 40, 5]
#
# For pass 7:
#     Now we compare 40 and 5, Since 5 is less than 40 we swap, 5 is less than 35 we swap, 5 is less than 30 we swap, 5 is less than 25 we swap, 5 is less than 20 we swap and 5 is less than 15 we swap and 5 is less than 10 we swap. Since 5 has no other element to be swap with so we end the pass there. Also since there are no other unsorted elemnent lest, we can conclude that every elements are in the right position.
# [5, 10, 15, 20, 25, 30, 35, 40]

# %%
arr = [5, 10, 15, 20, 25, 30, 35, 40]
insertion_sort(arr)
# Out:
# Total Number of Comparisons: 0
# Total Number of shifts: 0
# Total Number of Moves: 14
# [5, 10, 15, 20, 25, 30, 35, 40]

# %%
arr = [40, 35, 30, 25, 20, 15, 10, 5]
insertion_sort(arr)
# Out:
# Total Number of Comparisons: 28
# Total Number of shifts: 28
# Total Number of Moves: 14
# [5, 10, 15, 20, 25, 30, 35, 40]

# %% [raw]
# Insertion sort is better than selection sort because

# %% [markdown]
# ## Q3 (25%) — Iterative Merge Sort: Splitting & Merging
#
# Using the **iterative (non‑recursive)** Merge Sort from class, sort the list:
# ```
# [45, 23, 89, 12, 77, 34, 56, 90, 11, 67, 43, 28, 99, 61, 72]
# ```
# **Tasks**
# 1. Show how the list is divided into sublists at each iteration (i.e., the block size doubling progression).
# 2. Show how the sublists are merged step by step until the final sorted list is obtained.
# 3. In 2–4 sentences, compare the runtime growth of Merge Sort vs. Insertion Sort for large inputs.

# %%
def merge_subsets(src,dst,left,right,mid): 
    i = left
    j = mid
    k = left
    while i < mid and j < right: 
        if src[i] < src[j]:
            dst[k] = src[i]
            i+=1
        else:
            dst[k] = src[j]
            j+=1
        k+=1
    while j < right: 
        dst[k]=src[j]
        j+=1
        k+=1
    while i < mid: 
        dst[k]=src[i]
        i+=1
        k+=1

# %%
def merge_sort(arr): 
    n = len(arr)
    src = arr[:]
    dst = [None] * n
    size = 1
    while size < n: 
        for left in range(0,n,2*size):
            mid = min(left + size,n)
            right = min(left + size*2,n)
            merge_subsets(src,dst,left,right,mid)
        size*=2    
        src,dst = dst,src 
    return src

# %%
arr = [45, 23, 89, 12, 77, 34, 56, 90, 11, 67, 43, 28, 99, 61, 72]
merge_sort(arr)
# Out:
# [11, 12, 23, 28, 34, 43, 45, 56, 61, 67, 72, 77, 89, 90, 99]

# %% [raw]
# Given Array = [45, 23, 89, 12, 77, 34, 56, 90, 11, 67, 43, 28, 99, 61, 72]
# Sorting this array using the merge sorting algorithm
#
# Pass 1:
#     at pass 1, we first separate all the element of the array in a singularity form,
# [45] [23]
# [89] [12]
# [77] [34]
# [56] [90]
# [11] [67]
# [43] [28]
# [99] [61]
# [72]
#
# and then we merge the pairs of 1 into sorted pairs of 2
# [23,45]
# [12,89]
# [34,77]
# [56,90]
# [11,67]
# [28,43]
# [61,99]
# [72] - we live the odd pair as it is
#
# The array ends up looking like [23,45][12,89][34,77][56,90][11,67][28,43][61,99][72]
#
# Pass 2:
#     At this pass we increase the block size by 2
# [23,45][12,89]
# [34,77][56,90]
# [11,67][28,43]
# [61,99][72]
#
# now we merge them while sorting them in right positions
#
# [12,23,45,89]
# [34,56,77,90]
# [11,28,43,67]
# [61,72,99]
#
# The array ends up looking like [12,23,45,89][34,56,77,90][11,28,43,67][61,72,99]
#
# Pass 3:
#     now for this pass we increase the block size by 4 into groups of 8
# [12,23,45,89][34,56,77,90]
# [11,28,43,67][61,72,99]
#
# Now we merge them while sorting them
#
# [12,23,34,45,56,77,89,90]
# [11,28,43,61,67,72,99]
#
# The array ends up looking like [12,23,34,45,56,77,89,90][11,28,43,61,67,72,99]
#
# Pass 4:
#     Now we increase the block size by 8,
#
# [12,23,34,45,56,77,89,90][11,28,43,61,67,72,99]
#
# now we merge them while sorting it
#
# [11,12,23,28,34,43,45,56,61,67,72,77,89,90,99]
#
# Hence, the array is sorted follwing these steps in Merge sorting.

# %% [raw]
# Runtime growth of Merge Sort vs. Insertion Sort for large inputs.
#
# Merge Sort runs in O(nlogn) for every cases which means the number of operation grows slowly for large inputs elelemts of an Array. Whereas insertion sort runs in O(n^2) for most cases which means the number of operation grows way faster as the lenth ofthe array increases. For example for n = 10,000 lenth of operation, merge sort requires around 40,000 operations while insertion sort requires around 100,000,000 operations which is significantly longer than the merge sort. Insertion sort is only faster for very small n value.

# %% [markdown]
# ## Q4 (25%) — Iterative Quick (Code) Sort: Partitioning & Stack
#
# Using the **iterative Quick Sort** version from class (pivot = last element), sort the list:
# ```
# [88, 12, 56, 74, 33, 91, 47, 62, 5, 39, 18, 70, 25, 99, 41]
# ```
# **Tasks**
# 1. Show how the partitioning operates at each major step (pivot chosen, final pivot index, array state after partition).
# 2. Show how the stack/list of sub‑ranges changes during the iterative process.
# 3. Briefly discuss how choosing the first element as pivot (instead of the last) could impact performance depending on input order.

# %%
def partition(arr,low,high):
    pivot = arr[high]
    i = low - 1
    for j in range(low,high):
        if arr[j] <= pivot: 
            i+=1
            arr[i],arr[j] = arr[j],arr[i]
    arr[i+1],arr[high] = arr[high],arr[i+1]
    return i+1

# %%
arr = [88, 12, 56, 74, 33, 91, 47, 62, 5, 39, 18, 70, 25, 99, 41]

# %%
partition(arr,0,14)
# Out:
# 6

# %%
def quick_sort(arr):
    stack = [(0,len(arr)-1)]
    while stack:
        low,high = stack.pop()
        if low < high:
            p = partition(arr,low,high)
            left_len = p - low
            right_len = high - p
            if left_len > right_len:
                if low < p-1:
                    stack.append((low,p-1))
                if p+1 < high:
                    stack.append((p+1,high))          
            else:
                if p+1 < high:
                    stack.append((p+1,high))
                if low < p-1:
                    stack.append((low,p-1))
    return arr

# %%
quick_sort(arr)
# Out:
# [5, 12, 18, 25, 33, 39, 41, 47, 56, 62, 70, 74, 88, 91, 99]

# %% [raw]
# Here,
# Step 1:
#
# the stack starts with: (0,14)
# [88, 12, 56, 74, 33, 91, 47, 62, 5, 39, 18, 70, 25, 99, 41]
# Chosen pivot = 14 i.e 41 (last element)
#
# What we do here is put everything that is smaller than 41 to the left and everything that is bigger to the right.
# We get,
# [12, 33, 5, 39, 18, 25, 41, 88, 56, 74, 91, 47, 62, 70, 99]
# 41 lands at the index 6.
#
# left side: [12, 33, 5, 39, 18, 25]
# right side: [88, 56, 74, 91, 47, 62, 70, 99]
#
# After this the stack is (0,5)(7,14)
#
# Step 2:
#
# we go through the right side also identified as (7,14) in the stack.
# [88, 56, 74, 91, 47, 62, 70, 99]
# now since the pivot element is the last element, which in this case is 99, we move everything that is smaller than 99 to the left side and everything that is bigger than 99 to the right side.
# Since no number is bigger than 99 in this side, we will only have one side.
#
# left side:[88, 56, 74, 91, 47, 62, 70]
#
# After this the stack is (0,5)(7,12)
#
# Step 3:
#
# Now we go through (7,12) in the stack and do the same select the last number as the pivot number. in this case which is 70.
# we now separate the numebrs bigger ans smaller than 70 to left and right side respectively. we get,
# [56, 47, 62, 70, 88, 74, 91]
# left side: [56,47,62]
# right side: [88,74,91]
#
# after this the stack is (0,5)(7,9)(11,12)
#
# Step 4:
#
# Take (11,12) and repeat the process, last element i.e. 91
# [88, 74, 91]
# Since no number is bigger than 91, we will only have one side.
# left side: [74, 88]
# right side: nothing
# After this the stack is (0,5)(7,9)(11,11)
#
# Step 5:
# Take (7,9) and repeat the process, last element i.e. 62
# [56, 47, 62]
# Since no number is bigger than 62, we will only have one side.
# left side: [47, 56]
# right side: nothing
# After this the stack is (0,5)(7,8)
#
# Step 6:
# Take (7,8) and repeat the process, last element i.e. 56
# [47, 56]
# Since no number is bigger than 56, we will only have one side.
# left side: [47]
# right side: nothing
# After this the stack is (0,5)
#
# Step 7:
# Take (0,5) and repeat the process, last element i.e. 25
# [12, 33, 5, 39, 18, 25]
# we now separate the numbers bigger and smaller than 25 to right and left side respectively. we get,
# [12, 5, 18, 25, 33, 39]
# 25 lands at index 3.
# left side: [12, 5, 18]
# right side: [33, 39]
# After this the stack is (0,2)(4,5)
#
# Step 8:
# Take (4,5) and repeat the process, last element i.e. 39
# [33, 39]
# Since no number is bigger than 39, we will only have one side.
# left side: [33]
# right side: nothing
# After this the stack is (0,2)
#
# Step 9:
# Take (0,2) and repeat the process, last element i.e. 18
# [12, 5, 18]
# Since no number is bigger than 18, we will only have one side.
# left side: [5, 12]
# right side: nothing
# 18 lands at index 2.
# After this the stack is (0,1)
#
# Step 10:
# Take (0,1) and repeat the process, last element i.e. 12
# [5, 12]
# Since no number is bigger than 12, we will only have one side.
# left side: [5]
# right side: nothing
# Stack is now empty thus resulting in the array being sorted.
#
# [5, 12, 18, 25, 33, 39, 41, 47, 56, 62, 70, 74, 88, 91, 99]

# %% [raw]
# Briefly discuss how choosing the first element as pivot (instead of the last) could impact performance depending on input order.
#
# If we choose the first element as the pivot element instead of last, and in cases where the array is nearly sorted or sorted, the pivot element always ends up at the other end with nothing on the other side. This causes quick sort to degrade to O(n^2), which is the worst case.

# %% [markdown]
# ---
#
# **Submission Tips**
# - Keep traces readable (you may format as lists per step).
# - If your printing gets long, consider summarizing by showing **key steps** and include counts (e.g., how many merges, how many partitions).
# - Make sure your code runs end‑to‑end.
